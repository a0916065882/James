# %%
#1家分站30天的營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([8175, 5044, 1248, 2652, 4465, 5557,  189, 8179, 5951, 4471, 4424,
#        6553, 8595, 1614, 2025, 7541, 4528,  311, 5453, 6299, 8153, 8652,
#        3516, 5222, 1051, 4844, 1893, 8777, 1821, 4051], dtype=int32)

# %%
#累計每天這家店的營收
one_storecum = one_store.cumsum()
one_storecum
# Out:
# array([  8175,  13219,  14467,  17119,  21584,  27141,  27330,  35509,
#         41460,  45931,  50355,  56908,  65503,  67117,  69142,  76683,
#         81211,  81522,  86975,  93274, 101427, 110079, 113595, 118817,
#        119868, 124712, 126605, 135382, 137203, 141254])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31),one_storecum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
